# %%
import math
import matplotlib.pyplot as plt
import os

# ======================================================
# FUNÇÕES 1
# ======================================================

def soma(a, b):
    x = a + b
    print(f'\nA soma de {a} + {b} = {x}')

def subtracao(a, b):
    x = a - b
    print(f'\nA subtracao de {a} - {b} = {x}')

def multiplicacao(a, b):
    x = a * b
    print(f'\nA multiplicação de {a} * {b} = {x}')

def divisao(a, b):
    if b == 0:
        print("\nNão existe divisão por zero!")
        return
    x = a / b
    print(f'\nA divisão de {a} / {b} = {x}')

def operacoes_basicas():  
    os.system('cls')
    user_input = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Somar -------------------- 1\n'
                    'Subtrair ----------------- 2\n'
                    'Multiplicar -------------- 3\n'
                    'Dividir ------------------ 4\n\n'
                    'Selecionar: ')
    while user_input not in ['1', '2', '3', '4']:
        os.system('cls')
        print('Opção não encontrada!')
        user_input = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Somar -------------------- 1\n'
                    'Subtrair ----------------- 2\n'
                    'Multiplicar -------------- 3\n'
                    'Dividir ------------------ 4\n\n'
                    'Selecionar: ')

    a = float(input("Digite o 1º valor: "))

    b = float(input("Digite o 2º valor : "))

    os.system('cls')

    if user_input == '1':
        soma(a, b)
    elif user_input == '2':
        subtracao(a, b)
    elif user_input == '3':
        multiplicacao(a, b)
    elif user_input == '4':
        divisao(a, b)
    
    user = input("\nSelecione uma das opções abaixo: \n"
                 "Retornar ao menu de operações básicas ---- 1\n"
                 "Retornar ao menu principal --------------- n\n\n"
                 "Sua opção: ")
    while user not in ['1', 'n']:
        print('Opção não encontrada!\n')
        user = input("Selecione uma das opções abaixo: \n"
                 "Retornar ao menu de operações básicas ---- 1\n"
                 "Retornar ao menu principal --------------- n\n\n"
                 "Sua opção: ")
    
    if user == '1':
        operacoes_basicas()
    elif user == 'n':
        calculadora_cientifica()

# ======================================================
# FUNÇÃO 2
# ======================================================

def calc_potencia(): 
    print('\nPotenciação - Bª\n')

    base = input('Informe um valor para a base(B): ')
    while not base.replace('-','',1).replace('.','',1).isnumeric():
        print('\nSomente números!')
        base = input('Informe um valor para a base(B): ') 

    expoente = input('Informe um valor para o radical(ª): ')
    while not base.replace('-','',1).replace('.','',1).isnumeric():
        print('\nSomente números!')
        expoente = input('Informe um valor para o radical(ª): ')

    resultado = float(base) ** float(expoente)

    os.system('cls')
    
    print(f'\n{base} elevado a {expoente} é {resultado:,.2f}\n')

def calc_raiz():
        print('\nRadiciação - ª√B\n')

        base = input('Informe um valor para a base(B): ')
        while not base.replace('.','', 1).isdigit():
            print('\nSomente números positivos!')
            base = input('Informe um valor para a base(B): ') 

        radical = input('Informe um valor para o radical(ª): ')
        while not radical.isdigit():
            print('\nSomente números inteiro positivos!')
            radical = input('Informe um valor para o radical(ª): ')

        resultado = float(base) ** (1/int(radical))
        
        os.system('cls')

        print(f'\nA raiz {radical}ª de {base} é {resultado:,.2f}\n')

def menu_potencia_e_raiz():
    while True:
        opc = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Potênciação -------------------- 1\n'
                    'Radiciação --------------------- 2\n'
                    'Retornar ao menu principal ----- n\n\n'
                    'Selecionar: ').lower()

        if(opc == '1'):
            calc_potencia()
        elif(opc == '2'):
            calc_raiz()
        elif(opc == 'n'):
            calculadora_cientifica()
            break
        else:
            print('\nOpção não encontrada!\n')

# ======================================================
# FUNÇÃO 3
# ======================================================

def input_dados_para_conversao(tipo):
    # Input das unidades

    if(tipo in ['m', 'm²', 'm³', 'g']):
        lista_unidades = [f'k{tipo}', f'h{tipo}', f'da{tipo}', f'{tipo}', f'd{tipo}', f'c{tipo}', f'm{tipo}']
    elif(tipo == 'temperatura'):
        lista_unidades = ['ºc', 'ºf', 'k']
    elif(tipo == 'tempo'):
        lista_unidades = ['h', 'm', 's']
    else:
        lista_unidades = ['pb', 'tb', 'gb', 'mb', 'kb', 'b']

    unidade_1 = input(f'\nSelecione a unidade que deseja converter:\n'
                        f'{" | ".join(lista_unidades)}\n'
                        'Converter de: ').lower()
    while unidade_1 not in lista_unidades:
        print('\nOpção não encontrada, tente novamente!')
        unidade_1 = input(f'Selecione a unidade que deseja converter:\n'
                        f'{" | ".join(lista_unidades)}\n'
                        'Converter de: ').lower()
    
    lista_unidades.remove(unidade_1)
    
    unidade_2 = input(f'\nSelecione a unidade para qual deseja converter:\n'
                        f'{" | ".join(lista_unidades)}\n'
                        'Converter para: ').lower()
    while unidade_2 not in lista_unidades:
        print('\nOpção não encontrada, tente novamente!')
        unidade_2 = input(f'Selecione a unidade para qual deseja converter:\n'
                        f'{" | ".join(lista_unidades)}\n'
                        'Converter para: ').lower()

    # Input do valor

    valor = input(f'\n{unidade_1} ---> {unidade_2}\n'
                    'Informe um valor: ')
    while not valor.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        valor = input(f'{unidade_1} ---> {unidade_2}\n'
                    'Informe um valor: ')

    return [unidade_1, unidade_2, float(valor)]

def conversor_comprimento(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]

    if(unidade_1 == 'mm'):
        if(unidade_2 == 'cm'):
            res_conversao = valor / 10
        elif(unidade_2 == 'dm'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'm'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'dam'):
            res_conversao = valor / 10e+3
        elif(unidade_2 == 'hm'):
            res_conversao = valor / 10e+4
        else:
            res_conversao = valor / 10e+5
    elif(unidade_1 == 'cm'):
        if(unidade_2 == 'mm'):
            res_conversao = valor * 10
        elif(unidade_2 == 'dm'):
            res_conversao = valor / 10
        elif(unidade_2 == 'm'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'dam'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'hm'):
            res_conversao = valor / 10e+3
        else:
            res_conversao = valor / 10e+4
    elif(unidade_1 == 'dm'):
        if(unidade_2 == 'mm'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'cm'):
            res_conversao = valor * 10
        elif(unidade_2 == 'm'):
            res_conversao = valor / 10
        elif(unidade_2 == 'dam'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'hm'):
            res_conversao = valor / 10e+2
        else:
            res_conversao = valor / 10e+3
    elif(unidade_1 == 'm'):
        if(unidade_2 == 'mm'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'cm'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'dm'):
            res_conversao = valor * 10
        elif(unidade_2 == 'dam'):
            res_conversao = valor / 10
        elif(unidade_2 == 'hm'):
            res_conversao = valor / 10e+1
        else:
            res_conversao = valor / 10e+2
    elif(unidade_1 == 'dam'):
        if(unidade_2 == 'mm'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'cm'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'dm'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'm'):
            res_conversao = valor * 10
        elif(unidade_2 == 'hm'):
            res_conversao = valor / 10
        else:
            res_conversao = valor / 10e+1
    elif(unidade_1 == 'hm'):
        if(unidade_2 == 'mm'):
            res_conversao = valor * 10e+4
        elif(unidade_2 == 'cm'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'dm'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'm'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'dam'):
            res_conversao = valor * 10
        else:
            res_conversao = valor / 10
    else:
        if(unidade_2 == 'mm'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'cm'):
            res_conversao = valor * 10e+4
        elif(unidade_2 == 'dm'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'm'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'dam'):
            res_conversao = valor * 10e+1
        else:
            res_conversao = valor * 10

    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_area(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]

    if(unidade_1 == 'mm²'):
        if(unidade_2 == 'cm²'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'dm²'):
            res_conversao = valor / 10e+3
        elif(unidade_2 == 'm²'):
            res_conversao = valor / 10e+5
        elif(unidade_2 == 'dam²'):
            res_conversao = valor / 10e+7
        elif(unidade_2 == 'hm²'):
            res_conversao = valor / 10e+9
        else:
            res_conversao = valor / 10e+11
    elif(unidade_1 == 'cm²'):
        if(unidade_2 == 'm²'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'dm²'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'm²'):
            res_conversao = valor / 10e+3
        elif(unidade_2 == 'dam²'):
            res_conversao = valor / 10e+5
        elif(unidade_2 == 'hm²'):
            res_conversao = valor / 10e+7
        else:
            res_conversao = valor / 10e+9
    elif(unidade_1 == 'dm²'):
        if(unidade_2 == 'm²'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'cm²'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'm²'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'dam²'):
            res_conversao = valor / 10e+3
        elif(unidade_2 == 'hm²'):
            res_conversao = valor / 10e+5
        else:
            res_conversao = valor / 10e+7
    elif(unidade_1 == 'm²'):
        if(unidade_2 == 'm²'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'cm²'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'dm²'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'dam²'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'hm²'):
            res_conversao = valor / 10e+3
        else:
            res_conversao = valor / 10e+5
    elif(unidade_1 == 'dam²'):
        if(unidade_2 == 'm²'):
            res_conversao = valor * 10e+7
        elif(unidade_2 == 'cm²'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'dm²'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'm²'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'hm²'):
            res_conversao = valor / 10e+1
        else:
            res_conversao = valor / 10e+3
    elif(unidade_1 == 'hm²'):
        if(unidade_2 == 'mm²'):
            res_conversao = valor * 10e+9
        elif(unidade_2 == 'cm²'):
            res_conversao = valor * 10e+7
        elif(unidade_2 == 'dm²'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'm²'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'dam²'):
            res_conversao = valor * 10e+1
        else:
            res_conversao = valor / 10e+1
    else:
        if(unidade_2 == 'mm²'):
            res_conversao = valor * 10e+11
        elif(unidade_2 == 'cm²'):
            res_conversao = valor * 10e+9
        elif(unidade_2 == 'dm²'):
            res_conversao = valor * 10e+7
        elif(unidade_2 == 'm²'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'dam²'):
            res_conversao = valor * 10e+3
        else:
            res_conversao = valor * 10e+1

    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_volume(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]
    
    if(unidade_1 == 'mm³'):
        if(unidade_2 == 'cm³'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'dm³'):
            res_conversao = valor / 10e+5
        elif(unidade_2 == 'm³'):
            res_conversao = valor / 10e+7
        elif(unidade_2 == 'dam³'):
            res_conversao = valor / 10e+11
        elif(unidade_2 == 'hm³'):
            res_conversao = valor / 10e+14
        else:
            res_conversao = valor / 10e+17
    elif(unidade_1 == 'cm³'):
        if(unidade_2 == 'mm³'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'dm³'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'm³'):
            res_conversao = valor / 10e+5
        elif(unidade_2 == 'dam³'):
            res_conversao = valor / 10e+8
        elif(unidade_2 == 'hm³'):
            res_conversao = valor / 10e+11
        else:
            res_conversao = valor / 10e+14
    elif(unidade_1 == 'dm³'):
        if(unidade_2 == 'mm³'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'cm³'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'm³'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'dam³'):
            res_conversao = valor / 10e+5
        elif(unidade_2 == 'hm³'):
            res_conversao = valor / 10e+8
        else:
            res_conversao = valor / 10e+11
    elif(unidade_1 == 'm³'):
        if(unidade_2 == 'mm³'):
            res_conversao = valor * 10e+8
        elif(unidade_2 == 'cm³'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'dm³'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'dam³'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'hm³'):
            res_conversao = valor / 10e+5
        else:
            res_conversao = valor / 10e+8
    elif(unidade_1 == 'dam³'):
        if(unidade_2 == 'mm³'):
            res_conversao = valor * 10e+11
        elif(unidade_2 == 'cm³'):
            res_conversao = valor * 10e+8
        elif(unidade_2 == 'dm³'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'm³'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'hm³'):
            res_conversao = valor / 10e+2
        else:
            res_conversao = valor / 10e+5
    elif(unidade_1 == 'hm³'):
        if(unidade_2 == 'mm³'):
            res_conversao = valor * 10e+14
        elif(unidade_2 == 'cm³'):
            res_conversao = valor * 10e+11
        elif(unidade_2 == 'dm³'):
            res_conversao = valor * 10e+8
        elif(unidade_2 == 'm³'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'dam³'):
            res_conversao = valor * 10e+2
        else:
            res_conversao = valor / 10e+2
    else:
        if(unidade_2 == 'mm³'):
            res_conversao = valor * 10e+17
        elif(unidade_2 == 'cm³'):
            res_conversao = valor * 10e+14
        elif(unidade_2 == 'dm³'):
            res_conversao = valor * 10e+11
        elif(unidade_2 == 'm³'):
            res_conversao = valor * 10e+8
        elif(unidade_2 == 'dam³'):
            res_conversao = valor * 10e+5
        else:
            res_conversao = valor * 10e+2
        
    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_massa(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]
    
    if(unidade_1 == 'mg'):
        if(unidade_2 == 'cg'):
            res_conversao = valor / 10
        elif(unidade_2 == 'dg'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'g'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'dag'):
            res_conversao = valor / 10e+3
        elif(unidade_2 == 'hg'):
            res_conversao = valor / 10e+4
        else:
            res_conversao = valor / 10e+5
    elif(unidade_1 == 'cg'):
        if(unidade_2 == 'mg'):
            res_conversao = valor * 10
        elif(unidade_2 == 'dg'):
            res_conversao = valor / 10
        elif(unidade_2 == 'g'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'dag'):
            res_conversao = valor / 10e+2
        elif(unidade_2 == 'hg'):
            res_conversao = valor / 10e+3
        else:
            res_conversao = valor / 10e+4
    elif(unidade_1 == 'dg'):
        if(unidade_2 == 'mg'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'cg'):
            res_conversao = valor * 10
        elif(unidade_2 == 'g'):
            res_conversao = valor / 10
        elif(unidade_2 == 'dag'):
            res_conversao = valor / 10e+1
        elif(unidade_2 == 'hg'):
            res_conversao = valor / 10e+2
        else:
            res_conversao = valor / 10e+3
    elif(unidade_1 == 'g'):
        if(unidade_2 == 'mg'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'cg'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'dg'):
            res_conversao = valor * 10
        elif(unidade_2 == 'dag'):
            res_conversao = valor / 10
        elif(unidade_2 == 'hg'):
            res_conversao = valor / 10e+1
        else:
            res_conversao = valor / 10e+2
    elif(unidade_1 == 'dag'):
        if(unidade_2 == 'mg'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'cg'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'dg'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'g'):
            res_conversao = valor * 10
        elif(unidade_2 == 'hg'):
            res_conversao = valor / 10
        else:
            res_conversao = valor / 10e+1
    elif(unidade_1 == 'hg'):
        if(unidade_2 == 'mg'):
            res_conversao = valor * 10e+4
        elif(unidade_2 == 'cg'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'dg'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'g'):
            res_conversao = valor * 10e+1
        elif(unidade_2 == 'dag'):
            res_conversao = valor * 10
        else:
            res_conversao = valor / 10
    else:
        if(unidade_2 == 'mg'):
            res_conversao = valor * 10e+5
        elif(unidade_2 == 'cg'):
            res_conversao = valor * 10e+4
        elif(unidade_2 == 'dg'):
            res_conversao = valor * 10e+3
        elif(unidade_2 == 'g'):
            res_conversao = valor * 10e+2
        elif(unidade_2 == 'dag'):
            res_conversao = valor * 10e+1
        else:
            res_conversao = valor * 10
        
    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_dados(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]
    
    if(unidade_1 == 'b'):
        if(unidade_2 == 'kb'):
            res_conversao = valor / 1024
        elif(unidade_2 == 'mb'):
            res_conversao = valor / 1048576
        elif(unidade_2 == 'gb'):
            res_conversao = valor / 1073741824
        elif(unidade_2 == 'tb'):
            res_conversao = valor / 1099511627776
        else:
            res_conversao = valor / 1125899906842624
    elif(unidade_1 == 'kb'):
        if(unidade_2 == 'b'):
            res_conversao = valor * 1024
        elif(unidade_2 == 'mb'):
            res_conversao = valor / 1024
        elif(unidade_2 == 'gb'):
            res_conversao = valor / 1048576
        elif(unidade_2 == 'tb'):
            res_conversao = valor / 1073741824
        else:
            res_conversao = valor / 1099511627776
    elif(unidade_1 == 'mb'):
        if(unidade_2 == 'b'):
            res_conversao = valor * 1048576
        elif(unidade_2 == 'kb'):
            res_conversao = valor * 1024
        elif(unidade_2 == 'gb'):
            res_conversao = valor / 1024
        elif(unidade_2 == 'tb'):
            res_conversao = valor / 1048576
        else:
            res_conversao = valor / 1073741824
    elif(unidade_1 == 'gb'):
        if(unidade_2 == 'b'):
            res_conversao = valor * 1073741824
        elif(unidade_2 == 'kb'):
            res_conversao = valor * 1048576
        elif(unidade_2 == 'mb'):
            res_conversao = valor * 1024
        elif(unidade_2 == 'tb'):
            res_conversao = valor / 1024
        else:
            res_conversao = valor / 1048576
    elif(unidade_1 == 'tb'):
        if(unidade_2 == 'b'):
            res_conversao = valor * 1099511627776
        elif(unidade_2 == 'kb'):
            res_conversao = valor * 1073741824
        elif(unidade_2 == 'mb'):
            res_conversao = valor * 1048576
        elif(unidade_2 == 'gb'):
            res_conversao = valor * 1024
        else:
            res_conversao = valor / 1024
    else:
        if(unidade_2 == 'b'):
            res_conversao = valor * 1125899906842624
        elif(unidade_2 == 'kb'):
            res_conversao = valor * 1099511627776
        elif(unidade_2 == 'mb'):
            res_conversao = valor * 1073741824
        elif(unidade_2 == 'gb'):
            res_conversao = valor * 1048576
        else:
            res_conversao = valor * 1024
    
    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_temperatura(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]

    if(unidade_1 == 'ºc'):
        if(unidade_2 == 'ºf'):
            res_conversao = (valor * (9/5)) + 32
        else:
            res_conversao = valor + 273
    elif(unidade_1 == 'ºf'):
        if(unidade_2 == 'ºc'):
            res_conversao = (valor - 32) * 5/9
        else:
            res_conversao = (valor - 32) * 5/9 + 273.15
    else:
        if(unidade_2 == 'ºc'):
            res_conversao = valor - 273
        else:
            res_conversao = (valor - 273.15) * 9/5  + 32

    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_tempo(lista_dados):
    unidade_1 = lista_dados[0]
    unidade_2 = lista_dados[1]
    valor = lista_dados[2]

    if(unidade_1 == 'h'):
        if(unidade_2 == 's'):
            res_conversao = valor * (60 ** 2)
        else:
            res_conversao = valor * 60
    elif(unidade_1 == 'm'):
        if(unidade_2 == 's'):
            res_conversao = valor * 60
        else:
            res_conversao = valor / 60
    else:
        if(unidade_2 == 'm'):
            res_conversao = valor / 60
        else:
            res_conversao = valor / (60 ** 2)

    os.system('cls')
    print(f'\n{valor:,.2f} {unidade_1} é equivalente à {res_conversao:,} {unidade_2}\n')

    retorno_menu(conversor_unidades)

def conversor_unidades():
    os.system('cls')
    opc = input('\nPor favor, informe uma das opções abaixo:\n\n'
                    'Conversão de Comprimento ------- 1\n'
                    'Conversão de Área -------------- 2\n'
                    'Conversão de Volume ------------ 3\n'
                    'Conversão de Massa ------------- 4\n'
                    'Conversão de Dados ------------- 5\n'
                    'Conversão de Temperatura ------- 6\n'
                    'Conversão de Tempo ------------- 7\n'
                    'Retornar ao menu principal ----- n\n\n'
                    'Selecionar: ').lower()
    while opc not in ['1','2','3','4','5','6','7','n']:
        os.system('cls')
        print('Opção não encontrada, tente novamente!')
        opc = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Conversão de Comprimento ------- 1\n'
                    'Conversão de Área -------------- 2\n'
                    'Conversão de Volume ------------ 3\n'
                    'Conversão de Massa ------------- 4\n'
                    'Conversão de Dados ------------- 5\n'
                    'Conversão de Temperatura ------- 6\n'
                    'Conversão de Tempo ------------- 7\n'
                    'Retornar ao menu principal ----- n\n\n'
                    'Selecionar: ').lower()

    if(opc == '1'):
        conversor_comprimento(input_dados_para_conversao('m'))
    elif(opc == '2'):
        conversor_area(input_dados_para_conversao('m²'))
    elif(opc == '3'):
        conversor_volume(input_dados_para_conversao('m³'))
    elif(opc == '4'):
        conversor_massa(input_dados_para_conversao('g'))
    elif(opc == '5'):
        conversor_dados(input_dados_para_conversao('b'))
    elif(opc == '6'):
        conversor_temperatura(input_dados_para_conversao('temperatura'))
    elif(opc == '7'):
        conversor_tempo(input_dados_para_conversao('tempo'))
    else:
        calculadora_cientifica()
            

# ======================================================
# FUNÇÃO 4
# ======================================================

def seno(opcao):
    num_ang = 'número' if opcao == '1' else 'ângulo'

    num = float(input(f'Você quer o seno de que {num_ang}: '))

    resultado = math.sin(float(num)) if opcao == "1" else math.sin(math.radians(float(num)))

    os.system('cls')

    print(f'\nO seno de {num}{"" if int(opcao) == 1 else "º"} é {resultado:.2f}')

def cosseno(opcao):
    num_ang = 'número' if opcao == '1' else 'ângulo'

    num = float(input(f'Você quer o cosseno de que {num_ang}: '))

    resultado = math.cos(float(num)) if opcao == "1" else math.cos(math.radians(float(num)))

    os.system('cls')

    print(f'\nO cosseno de {num}{"" if int(opcao) == 1 else "º"} é {resultado:.2f}')

def tangente(opcao):
    num_ang = 'número' if opcao == '1' else 'ângulo'

    num = float(input(f'Você quer a tangente de que {num_ang}: '))

    resultado = math.tan(float(num)) if opcao == "1" else math.tan(math.radians(float(num)))
    
    os.system('cls')

    print(f'\nA tangente de {num}{"" if int(opcao) == 1 else "º"} é {resultado:.2f}')

def trigonometria():
    os.system('cls')
    user_input = input("\nSelecione uma das opções abaixo para utilizar: \n"
                 "Números ----------- 1\n"
                 "Ângulos ----------- 2\n\n"
                 "Sua opção: ")
    while user_input not in ['1', '2']:
        print('Apenas 1 ou 2')
        user_input = input("Selecione uma das opções abaixo para utilizar: \n"
                 "Números ----------- 1\n"
                 "Ângulos ----------- 2\n\n"
                 "Sua opção: ")

    sct = input("\nSelecione uma das opções abaixo para utilizar: \n"
                 "Seno ------------- 1\n"
                 "Cosseno ---------- 2\n"
                 "Tangente --------- 3\n\n"
                 "Sua opção: ")
    while sct not in ['1', '2', '3']:
        print('Apenas 1, 2 ou 3')
        sct = input("Selecione uma das opções abaixo para utilizar: \n"
                 "Seno ------------- 1\n"
                 "Cosseno ---------- 2\n"
                 "Tangente --------- 3\n\n"
                 "Sua opção: ")
    
    if sct == '1':
        seno(user_input)
    
    elif sct == '2':
        cosseno(user_input)
    
    elif sct == '3':
        tangente(user_input)
    
    user = input("\nSelecione uma das opções abaixo: \n"
                 "Ver outro valor ---------------- 1\n"
                 "Voltar ao menu principal ------- n\n\n"
                 "Sua opção: ")
    while user not in ['1', 'n']:
        print('\nOpção não encontrada!\n')
        user = input("Selecione uma das opções abaixo: \n"
                 "Ver outro valor ---------------- 1\n"
                 "Voltar ao menu principal ------- n\n\n"
                 "Sua opção: ")
    if user == '1':
        trigonometria()
    elif user == 'n':
        calculadora_cientifica()

# ======================================================
# FUNÇÃO 5
# ======================================================

def calc_fatorial():
    numero = input('\nInforme um número inteiro: ')
    while not numero.isdecimal() or numero == '0':
        print('\nSomente números inteiros positivos!')
        numero = input('Informe um número inteiro: ')
    fatorial = 1

    for elemento in range(1, int(numero) + 1):
        fatorial *= elemento
        
    os.system('cls')
    print(f'\n{numero}! = {fatorial}\n')

    menu_seleção = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Novo cálculo -------------------- 1\n'
                    'Retornar ao menu principal ------ n\n\n'
                    'Selecionar: ').lower()
    while menu_seleção not in ['1', 'n']:
        print('\nOpção não encontrada, tente novamente!\n')
        menu_seleção = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Novo cálculo -------------------- 1\n'
                    'Retornar ao menu principal ------ n\n\n'
                    'Selecionar: ').lower()

    if(menu_seleção == '1'):
        calc_fatorial()
    else:
        calculadora_cientifica()

# ======================================================
# FUNÇÃO 6
# ======================================================

def fazer_grafico():
    os.system('cls')
    print(" CONSTRUINDO GRÁFICO ".center(60, "*"))
    n = input("Digite a quantidade de pontos que você quer ver no gráfico de linhas: ")
    while not n.isdecimal():
        n = input("Digite um valor inteiro de pontos: ")
    n = int(n)

    x = []
    y = []
    for i in range(n):
        valor_x = float(input(f'Digite o valor de X do {i+1}º ponto: '))
        valor_y = float(input(f'Digite o valor de Y do {i+1}º ponto: '))

        x.append(valor_x)
        y.append(valor_y)

    os.system('cls')
    plt.figure(figsize = (7, 5)) 
    plt.plot(x, y)
    plt.title(f"Gráfico gerado por {n} pontos digitados")
    plt.grid()
    plt.show()

    menu = input('\nPor favor, informe uma das opções abaixo:\n\n'
                         'Novo gráfico -------------------- 1\n'
                         'Retornar ao menu principal ------ n\n\n'
                         'Selecionar: ').lower()
    while menu not in ['1', 'n']:
        print('\nOpção não encontrada, tente novamente!\n')
        menu = input('Por favor, informe uma das opções abaixo:\n\n'
                             'Novo gráfico -------------------- 1\n'
                             'Retornar ao menu principal ------ n\n\n'
                             'Selecionar: ').lower()

    if menu == '1':
        fazer_grafico()
    elif menu == 'n':
        calculadora_cientifica()

# ======================================================
# FUNÇÃO 7
# ======================================================

def quadrado(selecao):
    lado = input('\nInforme o valor do lado do quadrado: ')
    while not lado.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        lado = input('Informe o valor do lado do quadrado: ')

    resultado = float(lado) ** 2 if(selecao == 'Área') else float(lado) * 4

    os.system('cls')
    print(f'\n{selecao} de um quadrado de lado {lado} é {resultado:,.2f}.\n')

    retorno_menu(menu_area_ou_perimetro, selecao)

def retangulo(selecao):
    base = input('\nInforme o valor da base do retângulo: ')
    while not base.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        base = input('Informe o valor da base do retângulo: ')

    altura = input('Informe o valor da altura do retângulo: ')
    while not altura.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        altura = input('Informe o valor da altura do retângulo: ')

    resultado = float(base) * float(altura) if(selecao == 'Área') else (float(base) + float(altura)) * 2
    
    os.system('cls')
    print(f'\n{selecao} de um retângulo de base {base} e altura {altura} é {resultado:,.2f}.\n')

    retorno_menu(menu_area_ou_perimetro, selecao)

def triangulo(selecao):
    if(selecao == 'Área'):
        base = input('\nInforme o valor da base do triângulo: ')
        while not base.replace('.','', 1).isdigit():
            print('\nSomente números positivos!')
            base = input('Informe o valor da base do triângulo: ')

        altura = input('Informe o valor da altura do triângulo: ')
        while not altura.replace('.','', 1).isdigit():
            print('\nSomente números positivos!')
            altura = input('Informe o valor da altura do triângulo: ')
    else:
        lado = input('\nInforme o valor da lado do triângulo: ')
        while not lado.replace('.','', 1).isdigit():
            print('Somente números positivos!')
            lado = input('Informe o valor da lado do triângulo: ')

    resultado = (float(base) * float(altura)) / 2 if(selecao == 'Área') else float(lado) * 3

    os.system('cls')
    print(f'\n{selecao} de um triângulo de base {base} e altura {altura} é {resultado:,.2f}.\n')

    retorno_menu(menu_area_ou_perimetro, selecao)

def trapezio(selecao):
    base_maior = input('\nInforme o valor da base maior do trapézio: ')
    while not base_maior.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        base_maior = input('Informe o valor do base maior do trapézio: ')

    base_menor = input('Informe o valor da base menor do trapézio: ')
    while not base_menor.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        base_menor = input('Informe o valor do base menor do trapézio: ')

    if(selecao == 'Área'):
        altura = input('Informe o valor do altura do trapézio: ')
        while not altura.replace('.','', 1).isdigit():
            print('\nSomente números positivos!')
            altura = input('Informe o valor do altura do trapézio: ')
    else:
        inclinacao_esquerda = input('Informe o valor do inclinação esquerda do trapézio: ')
        while not inclinacao_esquerda.replace('.','', 1).isdigit():
            print('\nSomente números positivos!')
            inclinacao_esquerda = input('Informe o valor do inclinação esquerda do trapézio: ')

        inclinacao_direita = input('Informe o valor do inclinação direita do trapézio: ')
        while not inclinacao_direita.replace('.','', 1).isdigit():
            print('\nSomente números positivos!')
            inclinacao_direita = input('Informe o valor do inclinação direita do trapézio: ')

    resultado = ((float(base_maior) + float(base_menor)) * float(altura)) / 2 if(selecao == 'Área') else float(base_maior) + float(base_menor) + float(inclinacao_esquerda) + float(inclinacao_direita)

    os.system('cls')
    print(f'\n{selecao} de um trapézio de base maior {base_maior}, base menor {base_menor} e altura {altura} é {resultado:,.2f}.\n')

    retorno_menu(menu_area_ou_perimetro, selecao)

def circulo(selecao):
    raio = input('\nInforme o valor da raio do círculo: ')
    while not raio.replace('.','', 1).isdigit():
        print('\nSomente números positivos!')
        raio = input('Informe o valor do raio do círculo: ')

    resultado = (float(raio)**2) * math.pi if(selecao == 'Área') else 2 *  math.pi * (float(raio))

    os.system('cls')
    print(f'\n{selecao} de um círculo com raio {raio} é {resultado:,.2f}.\n')

    retorno_menu(menu_area_ou_perimetro, selecao)

def menu_area_ou_perimetro(selecao):
    os.system('cls')

    q_linhas_a = 21 if selecao == 'Perímetro' else 16
    q_linhas_p = 20 if selecao == 'Perímetro' else 15
        
    opc = input('\nCalcular:\n\n'
                f'{selecao} de um quadrado ---------------------- 1\n'
                f'{selecao} de um retângulo --------------------- 2\n'
                f'{selecao} de um triângulo --------------------- 3\n'
                f'{selecao} de um trapézio ---------------------- 4\n'
                f'{selecao} de um círculo ----------------------- 5\n'
                f'Retornar ao menu anterior {"-" * q_linhas_a} 0\n'
                f'Retornar ao menu principal {"-" * q_linhas_p} n\n\n'
                f'Selecionar: ').lower()
    while opc not in ['0','1','2','3','4','5','n']:
        os.system('cls')
        print('Opção não encontrada, tente novamente!')
        opc = input('Calcular:\n\n'
                f'{selecao} de um quadrado ----------------------- 1\n'
                f'{selecao} de um retângulo ---------------------- 2\n'
                f'{selecao} de um triângulo ---------------------- 3\n'
                f'{selecao} de um trapézio ----------------------- 4\n'
                f'{selecao} de um círculo ------------------------ 5\n'
                f'Retornar ao menu anterior {"-" * q_linhas_a} 0\n'
                f'Retornar ao menu principal {"-" * q_linhas_p} n\n\n'
                f'Selecionar: ').lower()

    if(opc == '0'):
        menu_geometria()
    elif(opc == '1'):
        quadrado(selecao)
    elif(opc == '2'):
        retangulo(selecao)
    elif(opc == '3'):
        triangulo(selecao)
    elif(opc == '4'):
        trapezio(selecao)
    elif(opc == '5'):
        circulo(selecao)
    else:
        calculadora_cientifica()

def menu_geometria():
    os.system('cls')
    opc = input('\nPor favor, informe uma das opções abaixo:\n\n'
                'Área --------------------------- 1\n'
                'Perimetro ---------------------- 2\n'
                'Retornar ao menu principal ----- n\n\n'
                'Selecionar: ').lower()
    while opc not in ['1','2','n']:
        os.system('cls')
        print('Opção não encontrada, tente novamente!')
        opc = input('Por favor, informe uma das opções abaixo:\n\n'
                    'Área --------------------------- 1\n'
                    'Perimetro ---------------------- 2\n'
                    'Retornar ao menu principal ----- n\n\n'
                    'Selecionar: ').lower()

    if(opc == '1'):
        menu_area_ou_perimetro('Área')
    elif(opc == '2'):
        menu_area_ou_perimetro('Perímetro')
    else:
        calculadora_cientifica()

# ======================================================
# FUNÇÃO 8
# ======================================================

def bhaskara():
    os.system('cls')
    a = float(input("Digite o valor de a: "))

    b = float(input("Digite o valor de b: "))

    c = float(input("Digite o valor de c: "))

    if a == 0:
        print('\nSua equação não é de segundo grau!')
    
    delta = (b**2) - 4*a*c
    
    if delta < 0:
        print('\nSua equação não possui raízes reais!')
    
    elif delta == 0:
        x = -b / (2*a)
        print(f'\nSua raiz é unica e tem o valor: {x}')
    
    else:
        x1 = (-b + (delta**(1/2))) / (2*a) 
        x2 = (-b - (delta**(1/2))) / (2*a) 
        print(f'\nVocê possui duas raizes reais. x1 = {x1} e x2 = {x2}')

    menu_seleção = input('\nPor favor, informe uma das opções abaixo:\n\n'
                    'Fazer Bhaskara novamente ---------------- 1\n'
                    'Retornar ao menu principal -------------- n\n\n'
                    'Selecionar: ').lower()
    while menu_seleção not in ['1', 'n']:
        print('\nOpção não encontrada, tente novamente!\n')
        menu_seleção = input('\nPor favor, informe uma das opções abaixo:\n\n'
                    'Fazer Bhaskara novamente ---------------- 1\n'
                    'Retornar ao menu principal -------------- n\n\n'
                    'Selecionar: ').lower()

    if menu_seleção == '1':
        bhaskara()
    else:
        calculadora_cientifica()

def retorno_menu(funcao, parametro=''):
    if(funcao == menu_area_ou_perimetro):
        q_linhas_a = 13 if parametro == 'Área' else 8
        opc = input('Por favor, selecione uma das opções abaixo:\n\n'
                    f'Retornar ao menu de {parametro} {"-" * q_linhas_a} 0\n'
                    'Retornar ao menu principal ----------- n\n\n'
                    'Selecionar: ').lower()
        while opc not in ['0', 'n']:
            os.system('cls')
            print('Opção não encontrada, tente novamente!')
            opc = input('Por favor, selecione uma das opções abaixo:\n\n'
                    f'Retornar ao menu de {parametro} {"-" * q_linhas_a} 0\n'
                    'Retornar ao menu principal ----------- n\n\n'
                    'Selecionar: ').lower()
            
    else:
        opc = input('Por favor, selecione uma das opções abaixo:\n\n'
                    'Retornar ao menu de conversão de unidades ----- 0\n'
                    'Retornar ao menu principal -------------------- n\n\n'
                    'Selecionar: ').lower()
        
        while opc not in ['0', 'n']:
            os.system('cls')
            print('Opção não encontrada, tente novamente!')
            opc = input('Por favor, selecione uma das opções abaixo:\n\n'
                    'Retornar ao menu de conversão de unidades ----- 0\n'
                    'Retornar ao menu principal -------------------- n\n\n'
                    'Selecionar: ').lower()
    
    if(opc == '0' and parametro != ''):
        funcao(parametro)
    elif(opc == '0' and parametro == ''):
      funcao()
    else:
        calculadora_cientifica()

def calculadora_cientifica():
    os.system('cls')
    print(" CALCULADORA CIENTÍFICA ".center(60, "*"))

    user_input = input('Por favor, selecione uma das opções abaixo:\n\n'
                    'Operações básicas ------------- 1\n'
                    'Potencias e Raizes ------------ 2\n'
                    'Conversor de unidades --------- 3\n'
                    'Trigonometria ----------------- 4\n'
                    'Fatorial ---------------------- 5\n'
                    'Fazer Gráfico ----------------- 6\n'
                    'Geometria --------------------- 7\n'
                    'Bhaskara ---------------------- 8\n'
                    'Fechar Calculadora ------------ 0\n\n'
                    'Selecionar: ')
    while user_input not in ['1','2','3','4','5','6','7','8','0']:
        os.system('cls')
        print('Opção não encontrada, tente novamente!')
        user_input = input('Por favor, selecione uma das opções abaixo:\n\n'
                    'Operações básicas ------------- 1\n'
                    'Potencias e Raizes ------------ 2\n'
                    'Conversor de unidades --------- 3\n'
                    'Trigonometria ----------------- 4\n'
                    'Fatorial ---------------------- 5\n'
                    'Fazer Gráfico ----------------- 6\n'
                    'Geometria --------------------- 7\n'
                    'Bhaskara ---------------------- 8\n'
                    'Fechar Calculadora ------------ 0\n\n'
                    'Selecionar: ')

    os.system('cls')

    if user_input == '1':
        operacoes_basicas()
    elif user_input == '2':
        menu_potencia_e_raiz()
    elif user_input == '3':
        conversor_unidades()
    elif user_input == '4':
        trigonometria()
    elif user_input == '5':
        calc_fatorial()
    elif user_input == '6':
        fazer_grafico()
    elif user_input == '7':
        menu_geometria()
    elif user_input == '8':
        bhaskara()
    elif user_input == '0':
        print("Muito Obrigado por usar a calculadora!")

calculadora_cientifica()
